# %% [markdown]
# # IMPORTS

# %%
import math
import numpy  as np
import pandas as pd
import random
import sweetviz as sv
import seaborn as sns
import pickle
import warnings
import inflection
import seaborn as sns
import scikitplot as skplt

from scipy                           import stats  as ss
from boruta                          import BorutaPy
from matplotlib                      import pyplot as plt
from IPython.display                 import Image
from IPython.core.display            import HTML
from category_encoders               import TargetEncoder
from scipy.stats                     import shapiro
from scipy.stats                     import randint as sp_randint
from sklearn                         import preprocessing as pp
from sklearn                         import model_selection as ms
from sklearn                         import ensemble as en
from sklearn                         import neighbors as nh
from sklearn                         import linear_model    as lm
from sklearn.model_selection         import GridSearchCV
from sklearn.model_selection         import train_test_split
from sklearn.preprocessing           import RobustScaler, MinMaxScaler
from sklearn.ensemble                import RandomForestRegressor
from sklearn.ensemble                import AdaBoostClassifier
from sklearn.model_selection         import cross_val_score
from sklearn.tree                    import DecisionTreeClassifier
from sklearn                         import preprocessing as pp
from sklearn                         import model_selection as ms
from sklearn                         import ensemble as en
from sklearn                         import neighbors as nh
from sklearn                         import linear_model    as lm


warnings.filterwarnings( 'ignore' )

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ## Loading data

# %%
df_raw = pd.read_csv ('C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/data/train.csv', low_memory=False)

# %%
df_raw.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# ### Data Description

# %% [markdown]
# |Variable           | Description                                                                                               |
# |:-------------------|:---------------------------------------------------------------------------------------------------------|
# |id                 | Unique ID for the customer                                                                                |
# |Gender             | Gender of the customer                                                                                    |
# |Age                | Age of the customer                                                                                       |
# |Driving_License    | 0 - Customer does not have DL, 1 - Customer already has DL                                                |
# |Region_Code        | Unique code for the region of the customer                                                                |
# |Previously_Insured| 1 - Customer already has Vehicle Insurance, 0 - Customer doesn't have Vehicle Insurance                    |
# |Vehicle_Age        | Age of the Vehicle                                                                                        |
# |Vehicle_Damage     | 1 - Customer got his/her vehicle damaged in the past. 0 - Customer didn't get his/her vehicle damaged     |
# |Annual_Premium     | The amount customer needs to pay as premium in the year                                                   |
# |PolicySalesChannel | Anonymized Code for the channel of outreaching to the customer                                            |
# |Vintage            | Number of Days, Customer has been associated with the company                                             |
# |Response           | 1 - Customer is interested, 0 - Customer is not interested                                                |

# %% [markdown]
# # STEP 01 - DATA DESCRIPTION

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## Change Colmuns names

# %%
column_names = df1.columns
print(column_names)
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
new_cols = ['id', 'gender', 'age', 'driving_license', 'region_code', 'previously_insured', 'vehicle_age', 'vehicle_damage', 'annual_premium',
       'policy_sales_channel', 'vintage', 'response']
df1.columns = new_cols

# %%
df1.head()
# Out:
#    id  gender  age  driving_license  region_code  previously_insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   vehicle_age vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# ## Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df1.shape[0] ) )
print( 'Number of Cols: {}'.format( df1.shape[1] ) )
# Out:
# Number of Rows: 381109
# Number of Cols: 12

# %% [markdown]
# ## Data Types

# %%
df1.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# driving_license           int64
# region_code             float64
# previously_insured        int64
# vehicle_age              object
# vehicle_damage           object
# annual_premium          float64
# policy_sales_channel    float64
# vintage                   int64
# response                  int64
# dtype: object

# %% [markdown]
# ## Check NA

# %%
df1.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# driving_license         0
# region_code             0
# previously_insured      0
# vehicle_age             0
# vehicle_damage          0
# annual_premium          0
# policy_sales_channel    0
# vintage                 0
# response                0
# dtype: int64

# %% [markdown]
# ## Change Data Types - NA

# %% [markdown]
# ## Descriptive Statistics

# %%
df1.describe()
# Out:
#                   id            age  driving_license    region_code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        previously_insured  annual_premium  policy_sales_channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'])

# %%
# Central Tendency - Mean, Median
ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T 
d2 = pd.DataFrame( num_attributes.apply( min ) ).T 
d3 = pd.DataFrame( num_attributes.apply( max ) ).T 
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T 
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T 
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T 

# concatenar
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#              attributes     min       max     range           mean    median  \
# 0                    id     1.0  381109.0  381108.0  190555.000000  190555.0
# 1                   age    20.0      85.0      65.0      38.822584      36.0
# 2       driving_license     0.0       1.0       1.0       0.997869       1.0
# 3           region_code     0.0      52.0      52.0      26.388807      28.0
# 4    previously_insured     0.0       1.0       1.0       0.458210       0.0
# 5        annual_premium  2630.0  540165.0  537535.0   30564.389581   31669.0
# 6  policy_sales_channel     1.0     163.0     162.0     112.034295     133.0
# 7               vintage    10.0     299.0     289.0     154.347397     154.0
# 8              response     0.0       1.0       1.0       0.122563       0.0
#
#              std          skew    kurtosis
# 0  110016.691870  9.443274e-16   -1.200000
# 1      15.511591  6.725390e-01   -0.565655
# 2       0.046109 -2.159518e+01  464.354302
# ...

# %%
num_attributes.hist(figsize=(10,12));

# %% [markdown]
# # STEP 02 - FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %%
# vehicle damage
df2['vehicle_damage'] =  df2['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )

# %% [markdown]
# # STEP 03 - DATA FILTERING - NA

# %%
df3 = df2.copy()

# %% [markdown]
# # STEP 04 - EXPLORATORY DATA ANALYSIS

# %%
df4 = df3.copy()

# %%
report = sv.analyze (df4, target_feat='response')
report.show_html(filepath='../reports/sweetviz_report.html', open_browser=False)
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report ../reports/sweetviz_report.html was generated.

# %%
#display on the notebook
report.show_notebook(w=None, h=None, scale=None, layout='vertical')
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ## Considerantions from EDA
#
# - Individuals lacking a driving license show minimal interest in acquiring insurance coverage.
# - Existing insurance holders exhibit limited interest in procuring additional coverage, given the potential risk of data leakage.
# - Owners of newer vehicles display diminished interest in purchasing insurance.
# - Individuals with a history of vehicle damage demonstrate heightened interest in obtaining insurance coverage.
#
# - The data is imbalanced. If the results obtained in the first cycle of CRISP are poor, it may be beneficial to perform balancing in a new cycle.

# %% [markdown]
# # STEP 05 - DATA PREPARATION

# %%
df5 = df4.copy()

# %%
df5.head()
# Out:
#    id  gender  age  driving_license  region_code  previously_insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0   > 2 Years               1         40454.0                  26.0      217
# 1    1-2 Year               0         33536.0                  26.0      183
# 2   > 2 Years               1         38294.0                  26.0       27
# 3    < 1 Year               0         28619.0                 152.0      203
# 4    < 1 Year               0         27496.0                 152.0       39
#
#    response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# ## Encoder

# %%
# gender - Target Encoding
target_encode_gender = df5.groupby( 'gender' )['response'].mean()
df5.loc[:, 'gender'] = df5['gender'].map( target_encode_gender )
pickle.dump( target_encode_gender, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/target_encode_gender.pkl', 'wb' ) )

# %%
# vehicle_age - Ordinal Encoding
ordinal_mapping = {'< 1 Year': 1, '1-2 Year': 2, '> 2 Years': 3}
df5['vehicle_age'] = df5['vehicle_age'].map(ordinal_mapping)
pickle.dump( ordinal_mapping, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/ordinal_mapping_vehicle_age.pkl', 'wb' ) )

# %%
# policy_sales_channel - Frequency Encoding
fe_policy_sales_channel = df5['policy_sales_channel'].value_counts(normalize=True)
df5['policy_sales_channel'] = df5['policy_sales_channel'].map(fe_policy_sales_channel)
pickle.dump( fe_policy_sales_channel, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/fe_policy_sales_channel.pkl', 'wb' ) )

# %%
# region_code - Frequency Encoding
fe_region_code = df5['region_code'].value_counts(normalize=True)
df5['region_code'] = df5['region_code'].map(fe_region_code)
pickle.dump( fe_region_code, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/fe_region_code.pkl', 'wb' ) )

# %% [markdown]
# ## Normalization - NA

# %%
# Set a significance level
alpha = 0.05

# Apply the Shapiro-Wilk test to each column
test_results = df5.apply(lambda column: shapiro(column))

# Print the result for each column
for column, (stat, p_value) in test_results.items():
    if p_value > alpha:
        print(f"The distribution of column '{column}' appears TO BE  (p-value: {p_value:.4f})")
    else:
        print(f"The distribution of column '{column}' DOES NOT appear to be normal (p-value: {p_value:.4f})")
# Out:
# The distribution of column 'id' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'gender' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'age' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'driving_license' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'region_code' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'previously_insured' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'vehicle_age' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'vehicle_damage' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'annual_premium' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'policy_sales_channel' DOES NOT appear to be normal (p-value: 0.0000)
# The distribution of column 'vintage' DOES NOT appear to be normal (p-value: 0.0000)
# ...

# %% [markdown]
# ## Rescaling

# %%
# To determine whether to use Min-Max Scaler or Robust Scaler, it will be necessary to check for outliers in each column.
#sns.boxplot (df5['age']) #- Robust Scaler
#sns.boxplot (df5['annual_premium']) #- Robust Scaler
#sns.boxplot (df5['vintage']) #- Min-max Scaler

# %% [markdown]
# - Min-Max Scaler (data with fewer outliers)
# - Robust Scaler (data with many outliers)

# %%
rs = RobustScaler()
mms = MinMaxScaler()
#age - Robust Scaler
df5['age'] = rs.fit_transform( df5[['age']].values )
pickle.dump( rs, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/age_robust_scaler.pkl', 'wb' ) )


#annual_premium - Robust Scaler
df5['annual_premium'] = rs.fit_transform( df5[['annual_premium']].values )
pickle.dump( rs, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/annual_premium_robust_scaler.pkl', 'wb' ) )

#vintage - Min-max Scaler
df5['vintage'] = mms.fit_transform( df5[['vintage']].values )
pickle.dump( mms, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/vintage_minmax_scaler.pkl', 'wb' ) )

# %%
df5.head()
# Out:
#    id    gender       age  driving_license  region_code  previously_insured  \
# 0   1  0.138411  0.333333                1     0.279225                   0
# 1   2  0.138411  1.666667                1     0.024274                   0
# 2   3  0.138411  0.458333                1     0.279225                   0
# 3   4  0.138411 -0.625000                1     0.024224                   1
# 4   5  0.103902 -0.291667                1     0.047921                   1
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  \
# 0            3               1        0.585862              0.209127
# 1            2               0        0.124508              0.209127
# 2            3               1        0.441814              0.209127
# 3            1               0       -0.203401              0.353663
# 4            1               0       -0.278293              0.353663
#
#     vintage  response
# 0  0.716263         1
# 1  0.598616         0
# 2  0.058824         1
# ...

# %% [markdown]
# # STEP 06 - FEATURE SELECTION

# %%
df6 = df5.copy()

# %%
df6.head()
# Out:
#    id    gender       age  driving_license  region_code  previously_insured  \
# 0   1  0.138411  0.333333                1     0.279225                   0
# 1   2  0.138411  1.666667                1     0.024274                   0
# 2   3  0.138411  0.458333                1     0.279225                   0
# 3   4  0.138411 -0.625000                1     0.024224                   1
# 4   5  0.103902 -0.291667                1     0.047921                   1
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  \
# 0            3               1        0.585862              0.209127
# 1            2               0        0.124508              0.209127
# 2            3               1        0.441814              0.209127
# 3            1               0       -0.203401              0.353663
# 4            1               0       -0.278293              0.353663
#
#     vintage  response
# 0  0.716263         1
# 1  0.598616         0
# 2  0.058824         1
# ...

# %%
df6 = df6.drop(['id'], axis = 1)

# %%
df6.head()
# Out:
#      gender       age  driving_license  region_code  previously_insured  \
# 0  0.138411  0.333333                1     0.279225                   0
# 1  0.138411  1.666667                1     0.024274                   0
# 2  0.138411  0.458333                1     0.279225                   0
# 3  0.138411 -0.625000                1     0.024224                   1
# 4  0.103902 -0.291667                1     0.047921                   1
#
#    vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  \
# 0            3               1        0.585862              0.209127
# 1            2               0        0.124508              0.209127
# 2            3               1        0.441814              0.209127
# 3            1               0       -0.203401              0.353663
# 4            1               0       -0.278293              0.353663
#
#     vintage  response
# 0  0.716263         1
# 1  0.598616         0
# 2  0.058824         1
# 3  0.667820         0
# ...

# %% [markdown]
# ## Boruta as Feature Selector

# %%
# training dataset
X = df6.drop(['response'], axis = 1)
y = df6['response']

# Divide dataset train and test
X_train_n, X_test_n, y_train_n, y_test_n = train_test_split(X, y, test_size=0.3, random_state=42)

# Define RandomForestRegressor
rf = RandomForestRegressor(n_jobs=-1)

# %%
# Boruta
boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_n.values, y_train_n.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	9 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	10 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	11 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	12 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	13 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# Iteration: 	14 / 100
# Confirmed: 	1
# Tentative: 	1
# Rejected: 	8
# ...

# %%
#Best features
features_selected = boruta.support_.tolist()

features_selected_boruta = X_train_n.iloc[:,features_selected].columns.to_list()

features_selected_boruta
# Out:
# ['vehicle_damage']

# %% [markdown]
# ## Features Importancia

# %%
# training dataset
X = df6.drop(['response'], axis = 1)
y = df6['response']

# Divide dataset train and test
X_train_n, X_test_n, y_train_n, y_test_n = train_test_split(X, y, test_size=0.3, random_state=42)

df6 = pd.concat( [X_train_n, y_train_n], axis=1 )

# data preparation
x_train_n = df6.drop( ['response'], axis=1 )
y_train_n = y_train_n.values
rf.fit( x_train_n, y_train_n )
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
importances = rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
df = pd.DataFrame()
for i, j in zip( x_train_n, rf.feature_importances_ ):
    aux = pd.DataFrame( {'feature': i, 'importance': j}, index=[0] )
    df = pd.concat( [df, aux], axis=0 )
    
print( df.sort_values( 'importance', ascending=False ) )

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(x_train_n.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(x_train_n.shape[1]), indices)
plt.xlim([-1, x_train_n.shape[1]])
plt.show()
# Out:
# Feature ranking:
#                 feature  importance
# 0               vintage    0.258227
# 0        annual_premium    0.242589
# 0                   age    0.148206
# 0        vehicle_damage    0.124299
# 0           region_code    0.106387
# 0  policy_sales_channel    0.063551
# 0                gender    0.027557
# 0           vehicle_age    0.016805
# 0    previously_insured    0.011979
# 0       driving_license    0.000399

# %% [markdown]
# # STEP 07 - MACHINE LEARNING MODELING

# %%
df7 = df6.copy()

# %%
cols_selected = ['vintage','annual_premium','age','region_code','vehicle_damage', 'policy_sales_channel', 'previously_insured', 'response']

df_selected = df7[cols_selected]

# %%
df_selected.head()
# Out:
#     vintage  annual_premium       age  region_code  vehicle_damage  \
# 0  0.716263        0.585862  0.333333     0.279225               1
# 1  0.598616        0.124508  1.666667     0.024274               0
# 2  0.058824        0.441814  0.458333     0.279225               1
# 3  0.667820       -0.203401 -0.625000     0.024224               0
# 4  0.100346       -0.278293 -0.291667     0.047921               0
#
#    policy_sales_channel  previously_insured  response
# 0              0.209127                   0         1
# 1              0.209127                   0         0
# 2              0.209127                   0         1
# 3              0.353663                   1         0
# 4              0.353663                   1         0

# %%
x_train = df_selected.drop(['response'], axis = 1)
y_train = df_selected['response']


x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=42)

# %% [markdown]
# ## KNN

# %%
# model definition
knn_model = nh.KNeighborsClassifier( n_neighbors=7 )

# model training
knn_model.fit( x_train, y_train )

# model prediction - Poder de GENERALIZACAO 
yhat_knn = knn_model.predict_proba( x_test )

# %%
# Score - accuracy
scores = cross_val_score(knn_model, x_test, y_test)
print(scores.mean())
# Out:
# 0.8588508985391592

# %%
 # Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_knn );

# %% [markdown]
# ## Logistic Regressor

# %%
# model definition
lr_model = lm.LogisticRegression( random_state=42 ) 
pickle.dump( lr_model, open( 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora/parameter/lr_model.pkl', 'wb' ) )


# model training
lr_model.fit( x_train, y_train )

# model prediction
yhat_lr = lr_model.predict_proba( x_test )

# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_lr );

# %%
# Score - accuracy
scores = cross_val_score(lr_model, x_test, y_test)
print(scores.mean())
# Out:
# 0.8763436632117536

# %% [markdown]
# # STEP 08 - Ensemble

# %% [markdown]
# ## Extra Trees

# %%
# model definition
et = en.ExtraTreesClassifier( n_estimators=1000, n_jobs=-1, random_state=42 )

# model fit
et.fit( x_train, y_train )

# model predict
yhat_et = et.predict_proba( x_test )

# %%
# Score - accuracy
scores = cross_val_score(et, x_test, y_test)
print(scores.mean())

# %%
 # Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_et );

# %% [markdown]
# ## Adaboost

# %%
# model definition - its not necessary, adaboost use a decision tree as a classifier
base_estimator = DecisionTreeClassifier()

# Adabost
ada_v1 = AdaBoostClassifier(learning_rate=0.1, n_estimators=400)

# model fit
ada_v1.fit( x_train, y_train )
# model predict
hat_ada_v1 = ada_v1.predict_proba( x_test )

# %%
# Score - accuracy
scores = cross_val_score(ada_v1, x_test, y_test)
print(scores.mean())
# Out:
# 0.8763436632117536

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_ada_v1 );

# %% [markdown]
# # STEP 09 - Grid Search + Adaboost

# %%
# Randomizes Search
param_grid = {
    'algorithm': ['SAMME', 'SAMME.R'], 
    'learning_rate': [0.01, 0.1, 1],     
    'n_estimators': [50, 100, 200]       
}

n_iter_search = 20
grid_search_v1 = GridSearchCV(estimator = ada_v1, param_grid = param_grid, cv=5)

#Fit
grid_search_v1.fit(x_train, y_train)

# Best parameters
print("Best parameters:", grid_search_v1.best_params_)

# model predict
y_pred = grid_search_v1.predict(x_test)
# Out:
# Best parameters: {'algorithm': 'SAMME.R', 'learning_rate': 1, 'n_estimators': 50}

# %%
best_model = grid_search_v1.best_estimator_

# %%
# Score - accuracy
scores = cross_val_score(best_model, x_test, y_test)
print(scores.mean())
# Out:
# 0.8762999316883088

# %% [markdown]
# # STEP 10 - Deploy to Production

# %% [markdown]
# ## Health Insurance Class

# %%
import pickle
import numpy  as np
import pandas as pd

class HealthInsurance:
    
    def __init__( self ):
        self.home_path = 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora'
        self.annual_premium_robust_scaler =     pickle.load( open( self.home_path + 'parameter/annual_premium_robust_scaler.pkl' ) )
        self.age_robust_scaler =                pickle.load( open( self.home_path + 'parameter/age_robust_scaler.pkl' ) ) 
        self.vintage_minmax_scaler =            pickle.load( open( self.home_path + 'parameter/vintage_minmax_scaler.pkl' ) ) 
        self.target_encode_gender =             pickle.load( open( self.home_path + 'parameter/target_encode_gender.pkl' ) )
        self.fe_region_code =                   pickle.load( open( self.home_path + 'parameter/fe_region_code.pkl' ) )
        self.fe_policy_sales_channel =          pickle.load( open( self.home_path + 'parameter/fe_policy_sales_channel.pkl' ) )
        self.ordinal_mapping_vehicle_age =      pickle.load( open( self.home_path + 'parameter/ordinal_mapping_vehicle_age.pkl' ) )
        
    def data_cleaning( self, df1 ):
        # 1.1. Rename Columns
        new_cols = ['id', 'gender', 'age', 'driving_license', 'region_code', 'previously_insured', 'vehicle_age', 'vehicle_damage', 'annual_premium',
               'policy_sales_channel', 'vintage', 'response']
        df1.columns = new_cols

        return df1 

    
    def feature_engineering( self, df2 ):
        # 2.0. Feature Engineering

        # Vehicle Damage Number
        df2['vehicle_damage'] = df2['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )

        return df2
    
    
    def data_preparation( self, df5 ):
        # anual premium - StandarScaler
        df5['annual_premium'] = self.annual_premium_robust_scaler.transform( df5[['annual_premium']].values )

        # Age - MinMaxScaler
        df5['age'] = self.age_robust_scaler.transform( df5[['age']].values )

        # Vintage - MinMaxScaler
        df5['vintage'] = self.vintage_minmax_scaler.transform( df5[['vintage']].values )

        # gender - One Hot Encoding / Target Encoding
        df5.loc[:, 'gender'] = df5['gender'].map( self.target_encode_gender )

        # region_code - Target Encoding / Frequency Encoding
        df5.loc[:, 'region_code'] = df5['region_code'].map( self.fe_region_code )

        # policy_sales_channel - Target Encoding / Frequency Encoding
        df5.loc[:, 'policy_sales_channel'] = df5['policy_sales_channel'].map( self.fe_policy_sales_channel )
        
        # vehicle_age
        df5.loc[:, 'vehicle_age'] = df5['vehicle_age'].map( self.ordinal_mapping_vehicle_age )
        
        # Feature Selection
        cols_selected = ['vintage','annual_premium','age','region_code','vehicle_damage', 'policy_sales_channel', 'previously_insured', 'response']
        
        return df5[ cols_selected ]
    
    
    def get_prediction( self, model, original_data, test_data ):
        # model prediction
        pred = model.predict_proba( test_data )
        
        # join prediction into original data
        original_data['prediction'] = pred
        
        return original_data.to_json( orient='records', date_format='iso' )

# %% [markdown]
# ## API Handler

# %%
import pickle
import pandas as pd
from flask import Flask, request, Response
from healthinsurance.HealthInsurance import HealthInsurance

# loading model
path = 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora'
model = pickle.load( open( path + 'parameter/model/lr_model.pkl', 'rb' ) )

# initialize API
app = Flask( __name__ )

@app.route( '/heathinsurance/predict', methods=['POST'] )
def health_insurance_predict():
    test_json = request.get_json()
    
    if test_json: # there is data
        if isinstance( test_json, dict ): # unique example
            test_raw = pd.DataFrame( test_json, index=[0] )
            
        else: # multiple example
            test_raw = pd.DataFrame( test_json, columns=test_json[0].keys() )
            
        # Instantiate Rossmann class
        pipeline = HealthInsurance()
        
        # data cleaning
        df1 = pipeline.data_cleaning( test_raw )
        
        # feature engineering
        df2 = pipeline.feature_engineering( df1 )
        
        # data preparation
        df3 = pipeline.data_preparation( df2 )
        
        # prediction
        df_response = pipeline.get_prediction( model, test_raw, df3 )
        
        return df_response
    
    else:
        return Response( '{}', status=200, mimetype='application/json' )
    
if __name__ == '__main__':
    app.run( '0.0.0.0', debug=True )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 4
#       2 import pandas as pd
#       3 from flask import Flask, request, Response
# ----> 4 from healthinsurance.HealthInsurance import HealthInsurance
#       6 # loading model
#       7 path = 'C:/Users/prisc/OneDrive/Documentos/Dados/DS_prod/3_seguradora'
#
# ModuleNotFoundError: No module named 'healthinsurance.HealthInsurance'; 'healthinsurance' is not a package
